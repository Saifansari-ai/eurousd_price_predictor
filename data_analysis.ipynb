# %%
# import all required libraries for data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
# data reading
df1 = pd.read_csv('/home/saif/Desktop/forex_data/EUR_USD Historical Data112000_532019.csv')
df2 = pd.read_csv('/home/saif/Desktop/forex_data/EUR_USD Historical Data632019_2122025.csv')

# %%
df1.head(-1)
# Out:
#             Date   Price    Open    High     Low  Vol. Change %
# 0     05-03-2019  1.1306  1.1339  1.1353  1.1289   NaN   -0.27%
# 1     04-03-2019  1.1337  1.1379  1.1396  1.1309   NaN   -0.33%
# 2     01-03-2019  1.1374  1.1370  1.1410  1.1351   NaN    0.04%
# 3     28-02-2019  1.1370  1.1372  1.1422  1.1357   NaN    0.01%
# 4     27-02-2019  1.1369  1.1397  1.1405  1.1361   NaN   -0.14%
# ...          ...     ...     ...     ...     ...   ...      ...
# 4994  10-01-2000  1.0253  1.0288  1.0304  1.0213   NaN   -0.35%
# 4995  07-01-2000  1.0289  1.0323  1.0335  1.0255   NaN   -0.29%
# 4996  06-01-2000  1.0319  1.0322  1.0417  1.0272   NaN    0.05%
# 4997  05-01-2000  1.0314  1.0301  1.0405  1.0285   NaN    0.06%
# 4998  04-01-2000  1.0308  1.0251  1.0345  1.0213   NaN    0.45%
#
# [4999 rows x 7 columns]

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df2.head(-1)
# Out:
#             Date   Price    Open    High     Low  Vol. Change %
# 0     21-02-2025  1.0458  1.0501  1.0507  1.0448   NaN   -0.40%
# 1     20-02-2025  1.0500  1.0422  1.0504  1.0418   NaN    0.76%
# 2     19-02-2025  1.0421  1.0443  1.0462  1.0401   NaN   -0.23%
# 3     18-02-2025  1.0445  1.0484  1.0488  1.0435   NaN   -0.35%
# 4     17-02-2025  1.0482  1.0489  1.0507  1.0467   NaN   -0.09%
# ...          ...     ...     ...     ...     ...   ...      ...
# 1552  13-03-2019  1.1325  1.1288  1.1341  1.1277   NaN    0.35%
# 1553  12-03-2019  1.1286  1.1250  1.1308  1.1244   NaN    0.35%
# 1554  11-03-2019  1.1247  1.1239  1.1259  1.1222   NaN    0.08%
# 1555  08-03-2019  1.1238  1.1193  1.1248  1.1184   NaN    0.41%
# 1556  07-03-2019  1.1192  1.1307  1.1322  1.1176   NaN   -1.00%
#
# [1557 rows x 7 columns]

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
# merging df1 to df2 and converting it into a new csv file
df3 = pd.concat([df2,df1])
df3.to_csv('EUR_USD_price_2000_2025.csv')

# %%
df = pd.read_csv('EUR_USD_price_2000_2025.csv')

# %%
df.head(-1)
# Out:
#       Unnamed: 0        Date   Price    Open    High     Low  Change %  \
# 0              0  2000-03-02  0.9642  0.9732  0.9795  0.9614   -0.0095
# 1              1  2000-03-03  0.9597  0.9646  0.9680  0.9590   -0.0047
# 2              2  2000-03-06  0.9592  0.9577  0.9673  0.9560   -0.0005
# 3              3  2000-03-07  0.9596  0.9590  0.9628  0.9527    0.0004
# 4              4  2000-03-08  0.9605  0.9587  0.9632  0.9522    0.0009
# ...          ...         ...     ...     ...     ...     ...       ...
# 6508        6508  2025-02-13  1.0464  1.0387  1.0467  1.0373    0.0079
# 6509        6509  2025-02-14  1.0491  1.0465  1.0515  1.0446    0.0026
# 6510        6510  2025-02-17  1.0482  1.0489  1.0507  1.0467   -0.0009
# 6511        6511  2025-02-18  1.0445  1.0484  1.0488  1.0435   -0.0035
# 6512        6512  2025-02-19  1.0421  1.0443  1.0462  1.0401   -0.0023
#
#          SMA_7    SMA_30   SMA_100  ...  Lag_30    SMA_20    STD_20  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Change %', 'SMA_7', 'SMA_30',
#        'SMA_100', 'SMA_200', 'Day', 'Week', 'Month', 'Year', 'Price_Change',
#        'Gain', 'Loss', 'Avg_Gain', 'Avg_Loss', 'RS', 'RSI_14', 'EMA_12',
#        'EMA_26', 'MACD', 'Signal_Line', 'Lag_1', 'Lag_3', 'Lag_7',
#        'Target_Price', 'Lag_14', 'Lag_30', 'SMA_20', 'STD_20', 'Upper_Band',
#        'Lower_Band', 'High-Low', 'High-Close', 'Low-Close', 'TR', 'ATR_14'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # data analysis on Euro_usd_historical_data
# ## Data cleaning

# %%
# null values in the dataset
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# Price           0
# Open            0
# High            0
# Low             0
# Change %        0
# SMA_7           0
# SMA_30          0
# SMA_100         0
# SMA_200         0
# Day             0
# Week            0
# Month           0
# Year            0
# Price_Change    0
# Gain            0
# Loss            0
# Avg_Gain        0
# Avg_Loss        0
# RS              0
# RSI_14          0
# EMA_12          0
# EMA_26          0
# MACD            0
# Signal_Line     0
# Lag_1           0
# Lag_3           0
# Lag_7           0
# Target_Price    0
# Lag_14          0
# Lag_30          0
# SMA_20          0
# STD_20          0
# Upper_Band      0
# Lower_Band      0
# High-Low        0
# High-Close      0
# Low-Close       0
# TR              0
# ATR_14          0
# dtype: int64

# %% [markdown]
# * the Vol. column has no values
# * so romove the column Vol.

# %%
# drop Vol. column
df.drop('Vol.', axis=1, inplace=True)
df.head(-1)
# Out:
#       Unnamed: 0        Date   Price    Open    High     Low Change %
# 0              0  21-02-2025  1.0458  1.0501  1.0507  1.0448   -0.40%
# 1              1  20-02-2025  1.0500  1.0422  1.0504  1.0418    0.76%
# 2              2  19-02-2025  1.0421  1.0443  1.0462  1.0401   -0.23%
# 3              3  18-02-2025  1.0445  1.0484  1.0488  1.0435   -0.35%
# 4              4  17-02-2025  1.0482  1.0489  1.0507  1.0467   -0.09%
# ...          ...         ...     ...     ...     ...     ...      ...
# 6552        4994  10-01-2000  1.0253  1.0288  1.0304  1.0213   -0.35%
# 6553        4995  07-01-2000  1.0289  1.0323  1.0335  1.0255   -0.29%
# 6554        4996  06-01-2000  1.0319  1.0322  1.0417  1.0272    0.05%
# 6555        4997  05-01-2000  1.0314  1.0301  1.0405  1.0285    0.06%
# 6556        4998  04-01-2000  1.0308  1.0251  1.0345  1.0213    0.45%
#
# [6557 rows x 7 columns]

# %%
# romove unnamed column
df.drop('Unnamed: 0', axis=1, inplace=True)
df.head(-1)
# Out:
#             Date   Price    Open    High     Low  Change %     SMA_7  \
# 0     2000-03-02  0.9642  0.9732  0.9795  0.9614   -0.0095  0.977686
# 1     2000-03-03  0.9597  0.9646  0.9680  0.9590   -0.0047  0.971529
# 2     2000-03-06  0.9592  0.9577  0.9673  0.9560   -0.0005  0.966714
# 3     2000-03-07  0.9596  0.9590  0.9628  0.9527    0.0004  0.964629
# 4     2000-03-08  0.9605  0.9587  0.9632  0.9522    0.0009  0.963029
# ...          ...     ...     ...     ...     ...       ...       ...
# 6508  2025-02-13  1.0464  1.0387  1.0467  1.0373    0.0079  1.037457
# 6509  2025-02-14  1.0491  1.0465  1.0515  1.0446    0.0026  1.038729
# 6510  2025-02-17  1.0482  1.0489  1.0507  1.0467   -0.0009  1.040171
# 6511  2025-02-18  1.0445  1.0484  1.0488  1.0435   -0.0035  1.041857
# 6512  2025-02-19  1.0421  1.0443  1.0462  1.0401   -0.0023  1.043500
#
#         SMA_30   SMA_100   SMA_200  ...  Lag_30    SMA_20    STD_20  \
# 0     0.985223  0.997420  0.997420  ...  1.0172  0.983445  0.010607
# ...

# %%
# null values in the dataset
df.isnull().sum()
# Out:
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Change %    0
# dtype: int64

# %% [markdown]
# * now there is no null values in the dataset

# %%
# info of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6514 entries, 0 to 6513
# Data columns (total 40 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          6514 non-null   datetime64[ns]
#  1   Price         6514 non-null   float64
#  2   Open          6514 non-null   float64
#  3   High          6514 non-null   float64
#  4   Low           6514 non-null   float64
#  5   Change %      6514 non-null   float64
#  6   SMA_7         6514 non-null   float64
#  7   SMA_30        6514 non-null   float64
#  8   SMA_100       6514 non-null   float64
#  9   SMA_200       6514 non-null   float64
#  10  Day           6514 non-null   object
#  11  Week          6514 non-null   int64
#  12  Month         6514 non-null   int64
#  13  Year          6514 non-null   int64
#  14  Price_Change  6514 non-null   float64
#  15  Gain          6514 non-null   float64
#  16  Loss          6514 non-null   float64
# ...

# %% [markdown]
# * here the change% is object datatype but we need it as a float in order to do analysis
# * so changing the change % to float
# * the Date column is stored as string so change to Date

# %%
# changing the Change % to percentage between 0 and 1
df['Change %'] = df['Change %'].str.rstrip('%').astype('float') / 100

# %%
# changing the date column to datetime
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df.to_csv('/home/saif/Desktop/forex_data/EUR_USD_price_2000_2025.csv')

# %%
df.head()
# Out:
#         Date   Price    Open    High     Low  Change %
# 0 2025-02-21  1.0458  1.0501  1.0507  1.0448   -0.0040
# 1 2025-02-20  1.0500  1.0422  1.0504  1.0418    0.0076
# 2 2025-02-19  1.0421  1.0443  1.0462  1.0401   -0.0023
# 3 2025-02-18  1.0445  1.0484  1.0488  1.0435   -0.0035
# 4 2025-02-17  1.0482  1.0489  1.0507  1.0467   -0.0009

# %% [markdown]
# * now the values of change% is in between 0 and 1 to analyse better

# %%
# discription of the dataset
df.describe()
# Out:
#                                 Date        Price         Open         High  \
# count                           6558  6558.000000  6558.000000  6558.000000
# mean   2012-07-29 17:35:57.365050368     1.188373     1.188526     1.193745
# min              2000-01-03 00:00:00     0.827000     0.827000     0.832600
# 25%              2006-04-18 06:00:00     1.087725     1.088025     1.092400
# 50%              2012-07-30 12:00:00     1.179950     1.180100     1.184100
# 75%              2018-11-11 06:00:00     1.306375     1.306475     1.312200
# max              2025-02-21 00:00:00     1.598700     1.599600     1.603900
# std                              NaN     0.156476     0.156478     0.157106
#
#                Low     Change %
# count  6558.000000  6558.000000
# mean      1.183257     0.000023
# min       0.822700    -0.027600
# 25%       1.084025    -0.003300
# 50%       1.176100     0.000000
# 75%       1.301000     0.003200
# max       1.586500     0.037900
# ...

# %% [markdown]
# * no duplicates values in the dataset
# * no null values in the dataset

# %%
df.corr()
# Out:
#               Date     Price      Open      High       Low  Change %
# Date      1.000000 -0.019926 -0.019464 -0.024095 -0.014619 -0.013383
# Price    -0.019926  1.000000  0.999001  0.999537  0.999544  0.021100
# Open     -0.019464  0.999001  1.000000  0.999553  0.999543 -0.022659
# High     -0.024095  0.999537  0.999553  1.000000  0.999382 -0.000897
# Low      -0.014619  0.999544  0.999543  0.999382  1.000000 -0.000899
# Change % -0.013383  0.021100 -0.022659 -0.000897 -0.000899  1.000000

# %% [markdown]
# # Visualization on Euro-Usd dataset

# %%
# histogram on price,open,high,low
plt.figure(figsize=(20,20))
df.hist(column=['Price','Open','High','Low'])
plt.tight_layout()
plt.show()

# %% [markdown]
# * the distribution of price,close,high and low are symmitical
# * there is high correlation between these columns

# %%
# time vs price
plt.figure(figsize=(15,8))
plt.plot(df['Date'],df['Price'])
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Time vs Price')
plt.show()

# %% [markdown]
# * price from 2003 to 2008 were booming
# * then 2008 crisis happend then there were fall back of the market
# * after that the price has never recovered
# * from 2008 to 2015 the price were on avrg 1.3
# * then in 2015 the prices suddenly drop from 1.4 to 1.0 after that it never recover
# * after 2015 the prices stay on avrg 1.0
# * so overall from 2008 onwards the price is falling

# %%
# Heatmap of Correlations 
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# * price,open,high,low has perfect score of 1 means there are completely correlated
#
# # Feature engineering on euro-usd dataset
#
# ### moving average

# %%
df.sort_values(by="Date", inplace=True)

# Calculate Simple Moving Averages (SMA)
df["SMA_7"] = df["Price"].rolling(window=7, min_periods=1).mean()
df["SMA_30"] = df["Price"].rolling(window=30, min_periods=1).mean()
df["SMA_100"] = df["Price"].rolling(window=100, min_periods=1).mean()
df["SMA_200"] = df["Price"].rolling(window=200, min_periods=1).mean()

# Save the updated dataset (overwrite original CSV)
df.to_csv("EUR_USD_price_2000_2025.csv", index=False)

# %%
df.head()
# Out:
#            Date   Price    Open    High     Low  Change %     SMA_7    SMA_30  \
# 6557 2000-01-03  1.0262  1.0053  1.0282  1.0051    0.0191  1.026200  1.026200
# 6556 2000-01-04  1.0308  1.0251  1.0345  1.0213    0.0045  1.028500  1.028500
# 6555 2000-01-05  1.0314  1.0301  1.0405  1.0285    0.0006  1.029467  1.029467
# 6554 2000-01-06  1.0319  1.0322  1.0417  1.0272    0.0005  1.030075  1.030075
# 6553 2000-01-07  1.0289  1.0323  1.0335  1.0255   -0.0029  1.029840  1.029840
#
#        SMA_100   SMA_200
# 6557  1.026200  1.026200
# 6556  1.028500  1.028500
# 6555  1.029467  1.029467
# 6554  1.030075  1.030075
# 6553  1.029840  1.029840

# %% [markdown]
# ### Day of the week for every row

# %%
# Day of the week with name
df['Day'] = df['Date'].dt.day_name()
df.to_csv("EUR_USD_price_2000_2025.csv", index=False)
df.sample(5)
# Out:
#            Date   Price    Open    High     Low  Change %     SMA_7    SMA_30  \
# 6476 2000-04-25  0.9208  0.9384  0.9399  0.9164   -0.0187  0.939014  0.956957
# 5592 2003-09-17  1.1284  1.1174  1.1302  1.1136    0.0096  1.123914  1.110820
# 5133 2005-06-21  1.2177  1.2154  1.2188  1.2068    0.0026  1.213943  1.238673
# 3999 2009-10-26  1.4869  1.4997  1.5062  1.4844   -0.0087  1.495771  1.476827
# 4723 2007-01-16  1.2917  1.2939  1.2992  1.2908   -0.0014  1.294400  1.311747
#
#        SMA_100   SMA_200        Day  Week
# 6476  0.979216  0.979216    Tuesday    17
# 5592  1.139797  1.104986  Wednesday    38
# 5133  1.283941  1.288265    Tuesday    25
# 3999  1.434188  1.378504     Monday    44
# 4723  1.287653  1.277899    Tuesday     3

# %% [markdown]
# ### week of the year

# %%
# week of the year
df["Week"] = df["Date"].dt.isocalendar().week
df.to_csv("EUR_USD_price_2000_2025.csv", index=False)
df.sample(5)
# Out:
#            Date   Price    Open    High     Low  Change %     SMA_7    SMA_30  \
# 3018 2013-07-30  1.3262  1.3262  1.3303  1.3234    0.0002  1.324000  1.309130
# 3192 2012-11-28  1.2951  1.2942  1.2956  1.2880    0.0005  1.290971  1.287467
# 2091 2017-02-16  1.0672  1.0601  1.0681  1.0589    0.0070  1.063329  1.066847
# 4772 2006-11-08  1.2755  1.2772  1.2812  1.2745   -0.0012  1.275000  1.265033
# 5930 2002-05-31  0.9334  0.9369  0.9405  0.9281   -0.0035  0.927557  0.912570
#
#        SMA_100   SMA_200        Day  Week
# 3018  1.304632  1.308623    Tuesday    31
# 3192  1.268643  1.279743  Wednesday    48
# 2091  1.073745  1.096028   Thursday     7
# 4772  1.270772  1.251955  Wednesday    45
# 5930  0.886827  0.893241     Friday    22

# %% [markdown]
# ### Month of the year

# %%
# month of the year
df["Month"] = df["Date"].dt.month
df.to_csv("EUR_USD_price_2000_2025.csv", index=False)
df.sample(5)
# Out:
#            Date   Price    Open    High     Low  Change %     SMA_7    SMA_30  \
# 3398 2012-02-14  1.3118  1.3192  1.3217  1.3080   -0.0057  1.320243  1.299600
# 4718 2007-01-23  1.3024  1.2949  1.3047  1.2929    0.0059  1.295386  1.306850
# 4244 2008-11-17  1.2646  1.2545  1.2742  1.2514    0.0012  1.265114  1.301093
# 2006 2017-06-15  1.1143  1.1218  1.1230  1.1132   -0.0066  1.120471  1.113423
# 4661 2007-04-12  1.3485  1.3431  1.3504  1.3430    0.0041  1.341043  1.329517
#
#        SMA_100   SMA_200       Day  Week  Month
# 3398  1.331924  1.376802   Tuesday     7      2
# 4718  1.288310  1.279847   Tuesday     4      1
# 4244  1.437874  1.493706    Monday    47     11
# 2006  1.082738  1.082148  Thursday    24      6
# 4661  1.315668  1.294181  Thursday    15      4

# %%
# year of the date
df["Year"] = df["Date"].dt.year
df.to_csv("EUR_USD_price_2000_2025.csv", index=False)
df.sample(5)
# Out:
#            Date   Price    Open    High     Low  Change %     SMA_7    SMA_30  \
# 6005 2002-02-15  0.8732  0.8743  0.8746  0.8693   -0.0003  0.873414  0.876800
# 2966 2013-10-10  1.3519  1.3524  1.3546  1.3487   -0.0003  1.356343  1.340850
# 2112 2017-01-18  1.0630  1.0713  1.0717  1.0626   -0.0077  1.061800  1.052073
# 5287 2004-11-17  1.3036  1.2956  1.3049  1.2948    0.0062  1.294214  1.269603
# 5584 2003-09-29  1.1590  1.1460  1.1605  1.1395    0.0104  1.147500  1.114970
#
#        SMA_100   SMA_200        Day  Week  Month  Year
# 6005  0.889974  0.884865     Friday     7      2  2002
# 2966  1.324859  1.318717   Thursday    41     10  2013
# 2112  1.084520  1.103002  Wednesday     3      1  2017
# 5287  1.237114  1.227129  Wednesday    47     11  2004
# 5584  1.140306  1.109777     Monday    40      9  2003

# %% [markdown]
# ### RSI of the data

# %%
# Calculate daily price change
df["Price_Change"] = df["Price"].diff()

# Separate gains and losses
df["Gain"] = df["Price_Change"].apply(lambda x: x if x > 0 else 0)
df["Loss"] = df["Price_Change"].apply(lambda x: -x if x < 0 else 0)

# Calculate the 14-day average gain and loss
df["Avg_Gain"] = df["Gain"].rolling(window=14, min_periods=1).mean()
df["Avg_Loss"] = df["Loss"].rolling(window=14, min_periods=1).mean()

# Compute the Relative Strength (RS)
df["RS"] = df["Avg_Gain"] / df["Avg_Loss"]

# Compute RSI
df["RSI_14"] = 100 - (100 / (1 + df["RS"]))

# Save the updated dataset
df.to_csv("EUR_USD_price_2000_2025.csv", index=False)

df.sample(5)
# Out:
#            Date   Price    Open    High     Low  Change %     SMA_7    SMA_30  \
# 224  2024-04-15  1.0622  1.0637  1.0666  1.0619   -0.0019  1.075400  1.083497
# 3987 2009-11-11  1.4981  1.4982  1.5050  1.4952   -0.0001  1.489614  1.483227
# 1373 2019-11-19  1.1078  1.1072  1.1085  1.1062    0.0007  1.103771  1.107603
# 5418 2004-05-18  1.1954  1.2022  1.2041  1.1929   -0.0054  1.189671  1.195810
# 1889 2017-11-27  1.1896  1.1932  1.1961  1.1895   -0.0028  1.182257  1.172680
#
#        SMA_100   SMA_200  ... Week  Month  Year  Price_Change    Gain    Loss  \
# 224   1.086267  1.082635  ...   16      4  2024       -0.0020  0.0000  0.0020
# 3987  1.444869  1.389644  ...   46     11  2009       -0.0001  0.0000  0.0001
# 1373  1.109126  1.117569  ...   47     11  2019        0.0008  0.0008  0.0000
# 5418  1.231836  1.198462  ...   21      5  2004       -0.0065  0.0000  0.0065
# 1889  1.176959  1.135072  ...   48     11  2017       -0.0034  0.0000  0.0034
#
# ...

# %% [markdown]
# ### Moving Average Convergence Divergence

# %%
# Calculate the 12-day and 26-day EMA
df["EMA_12"] = df["Price"].ewm(span=12, adjust=False).mean()
df["EMA_26"] = df["Price"].ewm(span=26, adjust=False).mean()

# Calculate MACD Line
df["MACD"] = df["EMA_12"] - df["EMA_26"]

# Calculate Signal Line (9-day EMA of MACD)
df["Signal_Line"] = df["MACD"].ewm(span=9, adjust=False).mean()

# Save the updated dataset
df.to_csv("EUR_USD_price_2000_2025.csv", index=False)

df.sample(5)
# Out:
#            Date   Price    Open    High     Low  Change %     SMA_7    SMA_30  \
# 6015 2002-02-01  0.8619  0.8587  0.8645  0.8563    0.0043  0.864586  0.882007
# 599  2022-11-07  1.0019  0.9911  1.0035  0.9899    0.0059  0.989529  0.983347
# 5497 2004-01-28  1.2479  1.2641  1.2665  1.2464   -0.0127  1.258429  1.256023
# 3006 2013-08-15  1.3346  1.3256  1.3364  1.3206    0.0069  1.331671  1.318190
# 2708 2014-10-07  1.2668  1.2656  1.2683  1.2584    0.0013  1.263457  1.287683
#
#        SMA_100   SMA_200  ...    Gain   Loss  Avg_Gain  Avg_Loss        RS  \
# 6015  0.895002  0.885718  ...  0.0037  0.000  0.000893  0.003200  0.279018
# 599   1.004590  1.046242  ...  0.0059  0.000  0.004107  0.002914  1.409314
# 5497  1.198278  1.168567  ...  0.0000  0.016  0.004357  0.006364  0.684624
# 3006  1.309206  1.311126  ...  0.0091  0.000  0.002343  0.001857  1.261538
# 2708  1.332396  1.353093  ...  0.0016  0.000  0.001971  0.003379  0.583510
#
# ...

# %% [markdown]
# ### lag feature of 1,3,7 days
# **1-Day Lag (Lag_1)**
# * Captures short-term trends
# * Helps predict immediate price movement
# * Useful for high-frequency trading models
#
# **3-Day Lag (Lag_3)**
# * Identifies weekly cycle patterns
# * Good for short-term swing trading
# * Helps detect recent momentum shifts
#
# **7-Day Lag (Lag_7)**
# * Captures weekly trends
# * Useful for medium-term trading strategies
# * Can detect patterns in forex market cycles

# %%
# Add lag features
df["Lag_1"] = df["Price"].shift(1)
df["Lag_3"] = df["Price"].shift(3)
df["Lag_7"] = df["Price"].shift(7)


# Save the updated dataset
df.to_csv("EUR_USD_price_2000_2025.csv", index=False)
df.head(10)
# Out:
#            Date   Price    Open    High     Low  Change %     SMA_7    SMA_30  \
# 6557 2000-01-03  1.0262  1.0053  1.0282  1.0051    0.0191  1.026200  1.026200
# 6556 2000-01-04  1.0308  1.0251  1.0345  1.0213    0.0045  1.028500  1.028500
# 6555 2000-01-05  1.0314  1.0301  1.0405  1.0285    0.0006  1.029467  1.029467
# 6554 2000-01-06  1.0319  1.0322  1.0417  1.0272    0.0005  1.030075  1.030075
# 6553 2000-01-07  1.0289  1.0323  1.0335  1.0255   -0.0029  1.029840  1.029840
# 6552 2000-01-10  1.0253  1.0288  1.0304  1.0213   -0.0035  1.029083  1.029083
# 6551 2000-01-11  1.0332  1.0256  1.0341  1.0242    0.0077  1.029671  1.029671
# 6550 2000-01-12  1.0310  1.0329  1.0370  1.0259   -0.0021  1.030357  1.029837
# 6549 2000-01-13  1.0252  1.0309  1.0319  1.0237   -0.0056  1.029557  1.029322
# 6548 2000-01-14  1.0125  1.0258  1.0276  1.0113   -0.0124  1.026857  1.027640
#
#        SMA_100   SMA_200  ...  Avg_Loss        RS      RSI_14    EMA_12  \
# ...

# %% [markdown]
# ### Creating a target price column from price column
# * Target_Price that stores the next day's price, making it the target variable for a forecasting model

# %%
df['Target_Price'] = df['Price'].shift(-1)
df.to_csv("EUR_USD_price_2000_2025.csv", index=False)
df.head(10)
# Out:
#            Date   Price    Open    High     Low  Change %     SMA_7    SMA_30  \
# 6557 2000-01-03  1.0262  1.0053  1.0282  1.0051    0.0191  1.026200  1.026200
# 6556 2000-01-04  1.0308  1.0251  1.0345  1.0213    0.0045  1.028500  1.028500
# 6555 2000-01-05  1.0314  1.0301  1.0405  1.0285    0.0006  1.029467  1.029467
# 6554 2000-01-06  1.0319  1.0322  1.0417  1.0272    0.0005  1.030075  1.030075
# 6553 2000-01-07  1.0289  1.0323  1.0335  1.0255   -0.0029  1.029840  1.029840
# 6552 2000-01-10  1.0253  1.0288  1.0304  1.0213   -0.0035  1.029083  1.029083
# 6551 2000-01-11  1.0332  1.0256  1.0341  1.0242    0.0077  1.029671  1.029671
# 6550 2000-01-12  1.0310  1.0329  1.0370  1.0259   -0.0021  1.030357  1.029837
# 6549 2000-01-13  1.0252  1.0309  1.0319  1.0237   -0.0056  1.029557  1.029322
# 6548 2000-01-14  1.0125  1.0258  1.0276  1.0113   -0.0124  1.026857  1.027640
#
#        SMA_100   SMA_200  ...        RS      RSI_14    EMA_12    EMA_26  \
# ...

# %% [markdown]
# ### Adding lag_14 and lag_30 to capture longer trends

# %%
df["Lag_14"] = df["Price"].shift(14)
df["Lag_30"] = df["Price"].shift(30)

# Save the updated dataset
df.to_csv("EUR_USD_price_2000_2025.csv", index=False)
df.head()
# Out:
#          Date   Price    Open    High     Low  Change %     SMA_7    SMA_30  \
# 0  2000-01-03  1.0262  1.0053  1.0282  1.0051    0.0191  1.026200  1.026200
# 1  2000-01-04  1.0308  1.0251  1.0345  1.0213    0.0045  1.028500  1.028500
# 2  2000-01-05  1.0314  1.0301  1.0405  1.0285    0.0006  1.029467  1.029467
# 3  2000-01-06  1.0319  1.0322  1.0417  1.0272    0.0005  1.030075  1.030075
# 4  2000-01-07  1.0289  1.0323  1.0335  1.0255   -0.0029  1.029840  1.029840
#
#     SMA_100   SMA_200  ...    EMA_12    EMA_26      MACD  Signal_Line   Lag_1  \
# 0  1.026200  1.026200  ...  1.026200  1.026200  0.000000     0.000000     NaN
# 1  1.028500  1.028500  ...  1.026908  1.026541  0.000367     0.000073  1.0262
# 2  1.029467  1.029467  ...  1.027599  1.026901  0.000698     0.000198  1.0308
# 3  1.030075  1.030075  ...  1.028261  1.027271  0.000990     0.000357  1.0314
# 4  1.029840  1.029840  ...  1.028359  1.027392  0.000967     0.000479  1.0319
#
# ...

# %% [markdown]
# ## Implementing volatility metrics to capture volatility
# 1. Bollinger Bands
# 2. ATR
#
# ### Bollinger Bands

# %%
# Calculate 20-day Simple Moving Average (SMA)
df['SMA_20'] = df['Price'].rolling(window=20).mean()

# Calculate Standard Deviation
df['STD_20'] = df['Price'].rolling(window=20).std()

# Calculate Upper and Lower Bollinger Bands
df['Upper_Band'] = df['SMA_20'] + (2 * df['STD_20'])
df['Lower_Band'] = df['SMA_20'] - (2 * df['STD_20'])

# Drop NaN values (first 20 rows will be NaN due to rolling window)
df = df.dropna()

# Save the updated dataset
df.to_csv("EUR_USD_price_2000_2025.csv", index=False)
df.head()
# Out:
#           Date   Price    Open    High     Low  Change %     SMA_7    SMA_30  \
# 30  2000-02-14  0.9785  0.9863  0.9920  0.9776   -0.0080  0.984629  1.002793
# 31  2000-02-15  0.9812  0.9789  0.9863  0.9763    0.0028  0.984443  1.001140
# 32  2000-02-16  0.9866  0.9813  0.9876  0.9790    0.0055  0.985271  0.999647
# 33  2000-02-17  0.9877  0.9865  0.9957  0.9837    0.0011  0.985600  0.998173
# 34  2000-02-18  0.9862  0.9881  0.9904  0.9806   -0.0015  0.984514  0.996750
#
#      SMA_100   SMA_200  ...   Lag_1   Lag_3   Lag_7  Target_Price  Lag_14  \
# 30  1.003548  1.003548  ...  0.9864  0.9938  0.9900        0.9812  1.0003
# 31  1.002850  1.002850  ...  0.9785  0.9850  0.9825        0.9866  1.0009
# 32  1.002358  1.002358  ...  0.9812  0.9864  0.9808        0.9877  0.9881
# 33  1.001926  1.001926  ...  0.9866  0.9785  0.9854        0.9862  0.9745
# 34  1.001477  1.001477  ...  0.9877  0.9812  0.9938        0.9872  0.9693
#
#     Lag_30    SMA_20    STD_20  Upper_Band  Lower_Band
# ...

# %% [markdown]
# ### ATR

# %%
# ATR Calculation
df['High-Low'] = df['High'] - df['Low']
df['High-Close'] = abs(df['High'] - df['Price'].shift(1))
df['Low-Close'] = abs(df['Low'] - df['Price'].shift(1))

# True Range (TR) is the max of the above three
df['TR'] = df[['High-Low', 'High-Close', 'Low-Close']].max(axis=1)

# ATR (14-day moving average of TR)
df['ATR_14'] = df['TR'].rolling(window=14).mean()

# Drop NaN values (first 14 rows will be NaN due to rolling window)
df = df.dropna()

# Save the updated dataset
df.to_csv("EUR_USD_price_2000_2025.csv", index=False)
df.head()
# Out:
#           Date   Price    Open    High     Low  Change %     SMA_7    SMA_30  \
# 43  2000-03-02  0.9642  0.9732  0.9795  0.9614   -0.0095  0.977686  0.985223
# 44  2000-03-03  0.9597  0.9646  0.9680  0.9590   -0.0047  0.971529  0.983583
# 45  2000-03-06  0.9592  0.9577  0.9673  0.9560   -0.0005  0.966714  0.981973
# 46  2000-03-07  0.9596  0.9590  0.9628  0.9527    0.0004  0.964629  0.980617
# 47  2000-03-08  0.9605  0.9587  0.9632  0.9522    0.0009  0.963029  0.979270
#
#      SMA_100   SMA_200  ...  Lag_30    SMA_20    STD_20  Upper_Band  \
# 43  0.997420  0.997420  ...  1.0172  0.983445  0.010607    1.004658
# 44  0.996582  0.996582  ...  1.0089  0.982305  0.011864    1.006033
# 45  0.995770  0.995770  ...  1.0075  0.981225  0.012943    1.007110
# 46  0.995000  0.995000  ...  1.0003  0.979935  0.013764    1.007463
# 47  0.994281  0.994281  ...  1.0009  0.978270  0.014011    1.006291
#
#     Lower_Band  High-Low  High-Close  Low-Close      TR    ATR_14
# ...

# %% [markdown]
# # Visualization on feature engineered columns

# %% [markdown]
# ### Visualization on the simple moving average
# **SMA_7 vs SMA_30**

# %%
# Define 5-year phases
years = list(range(2000, 2025, 5))
num_phases = len(years)

# Determine subplot grid size
rows = (num_phases // 2) + (num_phases % 2)  # Ensures enough rows
cols = 2  # 2 columns per row

# Create figure with multiple subplots
fig, axs = plt.subplots(rows, cols, figsize=(16, rows * 4))  
axs = axs.flatten()  # Flatten for easy indexing

# Plot each 5-year phase
for i, start_year in enumerate(years):
    # Filter data for the 5-year range
    df_subset = df[(df['Date'].dt.year >= start_year) & (df['Date'].dt.year < start_year + 5)]
    
    # Plot SMA_7 and SMA_30
    axs[i].plot(df_subset['Date'], df_subset['SMA_7'], label='SMA 7', color='blue')
    axs[i].plot(df_subset['Date'], df_subset['SMA_30'], label='SMA 30', color='orange')

    # Set labels and title
    axs[i].set_title(f'{start_year}-{start_year+4} (SMA_7 vs SMA_30)')
    axs[i].set_xlabel('Date')
    axs[i].set_ylabel('SMA Value')
    axs[i].legend()
    axs[i].grid(True)

# Remove extra empty subplots
for j in range(i + 1, len(axs)):
    fig.delaxes(axs[j])

# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion
#
# **When SMA_7 crosses above SMA_30 ("Golden Cross")**
# - **📈 Bullish Signal** – This suggests a potential uptrend, indicating that prices may continue rising. Traders may consider buying or holding long positions.
#
# **When SMA_7 crosses below SMA_30 ("Death Cross")**
# - **📉 Bearish Signal** – This suggests a potential downtrend, indicating that prices may continue falling. Traders may consider selling or shorting the asset.
#
# **If SMA_7 stays above SMA_30 for an extended period**
# - **🔼 Strong Uptrend** – Momentum is positive, and prices are likely in a sustained bullish phase.
#
# **If SMA_7 stays below SMA_30 for an extended period**
# - **🔽 Strong Downtrend** – Momentum is negative, and prices may keep declining.

# %% [markdown]
# **SMA_100 vs SMa_200**

# %%
# Define 5-year phases
years = list(range(2000, 2025, 5))
num_phases = len(years)

# Determine subplot grid size
rows = (num_phases // 2) + (num_phases % 2)  # Ensures enough rows
cols = 2  # 2 columns per row

# Create figure with multiple subplots
fig, axs = plt.subplots(rows, cols, figsize=(16, rows * 4))  
axs = axs.flatten()  # Flatten for easy indexing

# Plot each 5-year phase
for i, start_year in enumerate(years):
    # Filter data for the 5-year range
    df_subset = df[(df['Date'].dt.year >= start_year) & (df['Date'].dt.year < start_year + 5)]
    
    # Plot SMA_7 and SMA_30
    axs[i].plot(df_subset['Date'], df_subset['SMA_100'], label='SMA 100', color='blue')
    axs[i].plot(df_subset['Date'], df_subset['SMA_200'], label='SMA 200', color='orange')

    # Set labels and title
    axs[i].set_title(f'{start_year}-{start_year+4} (SMA_100 vs SMA_200)')
    axs[i].set_xlabel('Date')
    axs[i].set_ylabel('SMA Value')
    axs[i].legend()
    axs[i].grid(True)

# Remove extra empty subplots
for j in range(i + 1, len(axs)):
    fig.delaxes(axs[j])

# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion
# **When SMA_100 crosses above SMA_200 ("Golden Cross")**
# - **📈 Strong Bullish Signal** – This indicates a long-term uptrend, signaling that the market is gaining strength. Institutional investors and long-term traders may consider buying or holding long positions.
#
# **When SMA_100 crosses below SMA_200 ("Death Cross")**
# - **📉 Strong Bearish Signal** – This suggests a long-term downtrend, meaning the market is losing strength. Traders may consider selling or shorting as prices could decline further.
#
# **If SMA_100 stays above SMA_200 for an extended period**
# - **🔼 Sustained Bull Market** – Indicates strong bullish momentum. The market is in an uptrend, and pullbacks are likely temporary corrections.
#
# **If SMA_100 stays below SMA_200 for an extended period**
# - **🔽 Sustained Bear Market** – Indicates strong bearish momentum. The market is in a downtrend, and rallies are likely short-lived before another drop.

# %% [markdown]
# ## Visualization on the Temporal feature of the data
#
# **day**

# %%
# Compute volatility (standard deviation of returns) for each weekday
weekday_volatility = df.groupby('Day')['Price_Change'].std()

# Reorder weekdays for better visualization
weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
weekday_volatility = weekday_volatility.reindex(weekday_order)

# Plot the volatility for each weekday
plt.figure(figsize=(10, 5))
sns.barplot(x=weekday_volatility.index, y=weekday_volatility.values, palette='coolwarm')
plt.title('Volatility (Standard Deviation of Returns) by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Volatility (Std Dev of Returns)')
plt.grid(axis='y')

plt.show()

# %% [markdown]
# ### Conclusion
# - the forex market on only open on weekdays
# - the market is less volatile on the opening day (monday)
# - throughout the week the volatility increases
# - on the closing day of the weekday or of market(friday) the maket is most volatile due to closing of the market
# - then market open on monday
#
# ### week

# %%
# Compute weekly volatility (standard deviation of returns for each week)
weekly_volatility = df.groupby('Week')['Price_Change'].std()

# Plot the volatility for each week of the year
plt.figure(figsize=(12, 6))
sns.lineplot(x=weekly_volatility.index, y=weekly_volatility.values, marker='o', color='blue')
plt.title('Volatility (Std Dev of Returns) by Week of the Year')
plt.xlabel('Week of the Year')
plt.ylabel('Volatility (Std Dev of Returns)')
plt.grid(True)

plt.show()

# %% [markdown]
# ## Conclusion
# **High Volatility Periods:**
#
# - The highest volatility occurs around Week 10 (early March).
# - Another increase is seen between Weeks 40-45 (October-November).
# - These spikes might be linked to economic announcements, geopolitical events, or seasonal trends.
#
# **Low Volatility Periods:**
#
# - Around Week 50-52 (December), volatility drops sharply, likely due to reduced trading activity near the year-end holidays.
# - There are also brief dips around Weeks 15-20 (April-May), which may indicate calmer market conditions.
#
# **General Trend:**
#
# - Volatility fluctuates throughout the year but generally remains between 0.005 and 0.008.
# - Sudden spikes suggest market uncertainty, while stable periods indicate lower price fluctuations.
#
# ## Months

# %%
# Compute volatility (standard deviation of returns) per month
monthly_volatility = df.groupby('Month')['Price_Change'].std()

# Plot the monthly volatility
plt.figure(figsize=(10, 5))
plt.plot(monthly_volatility.index, monthly_volatility, marker='o', linestyle='-', color='blue')
plt.xlabel('Month')
plt.ylabel('Volatility (Std Dev of Returns)')
plt.title('Volatility by Month')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Conclusion
# **High Volatility Months:**
#
# - March (3rd month) and April (4th month) show significant volatility spikes.
# - October (10th month) and November (11th month) also exhibit increased fluctuations.
# - This could be due to economic reports, central bank decisions, or major financial events occurring in these months.
#
# **Low Volatility Months:**
#
# - February (2nd month), May (5th month), and August (8th month) show lower volatility.
# - This could be due to reduced trading activity, seasonal market effects, or lower economic uncertainties.
#
# **Trading Implications:**
#
# - Higher volatility months indicate greater price fluctuations, providing more trading opportunities but also increased risk.
# - Lower volatility months suggest stable trends, which may be better suited for conservative strategies like long-term holding.
#
# **Potential Actions:**
#
# - If trading short-term, focus on high-volatility months for potential breakout trades.
# - If investing long-term, low-volatility months may offer better entry points for stable trends.
#
# ## Visualization on the RSI_14 column

# %%
# Define 5-year phases
years = list(range(2000, 2025, 5))
num_phases = len(years)

# Determine subplot grid size
rows = num_phases  
cols = 2  

# Create figure with multiple subplots
fig, axs = plt.subplots(rows, cols, figsize=(16, rows * 4), sharex=False)  
axs = axs.flatten()  # Flatten for easy indexing

# Plot each 5-year phase
for i, start_year in enumerate(years):
    # Filter data for the 5-year range
    df_subset = df[(df['Date'].dt.year >= start_year) & (df['Date'].dt.year < start_year + 5)]
    
    # Plot EUR/USD Price
    axs[2*i].plot(df_subset['Date'], df_subset['Price'], label='EUR/USD Price', color='black')
    axs[2*i].set_title(f'{start_year}-{start_year+4} EUR/USD Price Chart')
    axs[2*i].set_ylabel('Price')
    axs[2*i].legend()
    axs[2*i].grid()

    # Plot RSI
    axs[2*i + 1].plot(df_subset['Date'], df_subset['RSI_14'], label='RSI (14-day)', color='blue')
    axs[2*i + 1].axhline(70, linestyle='--', color='red', label='Overbought (70)')
    axs[2*i + 1].axhline(30, linestyle='--', color='green', label='Oversold (30)')
    axs[2*i + 1].set_title(f'{start_year}-{start_year+4} RSI Indicator')
    axs[2*i + 1].set_xlabel('Date')
    axs[2*i + 1].set_ylabel('RSI Value')
    axs[2*i + 1].legend()
    axs[2*i + 1].grid()

# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion
# **Key Insights:**
#
# - Dividing the data into 5-year periods helps analyze long-term trends and identify major market movements (e.g., financial crises, economic recoveries, or strong up/down trends).
# - RSI indicator shows overbought (above 70) and oversold (below 30) zones, helping to identify potential trend reversals in different time periods.
# - Comparing different phases allows for better understanding of how market conditions evolved over the years, including periods of high volatility or stable trends.
#
# **Significance:**
# - Helps traders and analysts identify long-term patterns in price movements.
# - Highlights periods of high or low RSI, indicating when the market was potentially overbought or oversold.
# - Useful for strategy backtesting—checking if a trading strategy would have worked in different market conditions.
#
# **Interpretation**
#
#
# - If RSI > 70 → Overbought (possible sell signal).
# - If RSI < 30 → Oversold (possible buy signal).
#
# ## Visualization on the MACD and signal line

# %%
years = list(range(2000, 2025, 2))
num_phases = len(years)

# Determine subplot grid size
rows = (num_phases // 2) + (num_phases % 2)
cols = 2

# creating subplot
fig, axs = plt.subplots(rows,cols,figsize=(16,rows*4))
axs = axs.flatten()

# looping for the subplots
for i, start_year in enumerate(years):
    df_subset = df[(df['Date'].dt.year >= start_year) & (df['Date'].dt.year < start_year + 2)]
    
    axs[i].plot(df_subset['Date'],df_subset['MACD'],label='MACD',color='blue')
    axs[i].plot(df_subset['Date'],df_subset['Signal_Line'],label='Signal_Line',color='orange')

    axs[i].set_title(f'{start_year}-{start_year+2} MACD and Signal Line')
    axs[i].set_xlabel('Date')
    axs[i].legend()
    axs[i].grid(True)

# Remove extra empty subplots
for j in range(i + 1, len(axs)):
    fig.delaxes(axs[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion
# ### Interpreting MACD for Trading
#
# **✅ Bullish Signal:**
#
# - When MACD Line crosses above the Signal Line → Indicates a buy signal (uptrend).
# - When MACD is above zero → Confirms positive momentum.
#
# **❌ Bearish Signal:**
#
# - When MACD Line crosses below the Signal Line → Indicates a sell signal (downtrend).
# - When MACD is below zero → Confirms negative momentum.
